# %%
#cv2 is the standard library alias used for opencv in python
#we get all the major image processing function from cv2
import cv2

# %%
img =cv2.imread(r"D:\chat-app\0ed58cccd51c4758e634d0b29e8cb0c2.jpg")

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (919, 736, 3)

# %%
# %pip install matplotlib
import matplotlib.pyplot as plt
plt.imshow(img)
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
cv2.imshow("image",img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#Covert image into grayscale
gray =cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
# while True:
cv2.imshow("Gray MSD",gray)
cv2.waitKey(0)
    # if cv2.waitKey(1) & 0xFF == ord('q'):
        # break
cv2.destroyAllWindows()

# %%
# Pixel Manipulation
#ROI (Region of Interest) is a portion of an image that you want to focus on or manipulate. It is often used in image processing tasks to isolate specific areas of interest for analysis or modification.  
#

# %%
#Camscanner
#Image

# %%
#
